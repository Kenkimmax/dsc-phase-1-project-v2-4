# %% [markdown]
# ![100-Greatest-Movies-Variety.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Microsoft Movie Production Need Analysis

# %% [markdown]
# OVERVIEW
# The project analyzes was to provide actionable insight to the Microsoft Head of new movie Studio. The analysis used data from 3 sources namely: Movie_info, reviews and bom movie.
#
# Key Takeouts:
# Top 5 movie genre to produce fall under the five big catergorirs Action and Adventure|Classics|Drama, Drama|Science Fiction and Fantasy,Drama|Musical and Performing Arts, Drama|Mystery and Suspense and Drama|Kids and Family' 'Comedy
#
# The optimal Movie duration is critical to the Audience.
#
# Understading the different season patterns to release new movies.
#
# Speak into the production cost.

# %% [markdown]
# Methods
#
# This project uses descriptive analysis, including description of trends over time.This provides a useful overview of the movie industry with actionable insights to give the new Studio.

# %% [markdown]
# Results
#
# Movie release dates and day of the week are super important,as they play into the movie's marketing stategy. friday is the best day for movie premiere.

# %% [markdown]
# ![Best Movie Day.png](data:image/png;base64,...)

# %% [markdown]
# A majority of movies from 1921 are R rated.(Restricted)

# %% [markdown]
# ![Rating Categories.png](data:image/png;base64,...)

# %% [markdown]
# The ideal movie run time is between 1.5hours and 2.5hours with an average of 1.8hours(108 minutes)

# %% [markdown]
# ![Runtime.png](data:image/png;base64,...)

# %% [markdown]
# Popular movie genre fall under the broad Drama Category namely Action and Adventure,Science fiction and Fantasy, Musical and Performing Arts,Mystery and Suspense and Kids and Family respectively.

# %% [markdown]
# ![Top 10 Genres.png](data:image/png;base64,...)

# %% [markdown]
# The English Language as the original has a huge influence in the production of Movies.

# %% [markdown]
# ![Movie Language.png](data:image/png;base64,...)

# %% [markdown]
# A Huge number of movies made net earning after production costs estimated between 300M-500M US dollars.

# %% [markdown]
# ![Net earinng.png](data:image/png;base64,...)

# %% [markdown]
# Based on correlation alone, domestic earnings and foreign earnings have a relatively strong positive association.

# %% [markdown]
# ![Production Cost and Net Earning.png](data:image/png;base64,...)

# %% [markdown]
# The Movie Studio Top 10 Competitors.

# %% [markdown]
# ![Studio Competiton.png](data:image/png;base64,...)

# %% [markdown]
# Recommendations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Conclusions

# %% [markdown]
# ![image.png](data:image/png;base64,...)
